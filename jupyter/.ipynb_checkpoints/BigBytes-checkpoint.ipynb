# %% [markdown]
# # Big Bytes 2019

# %%
import numpy as np
import pandas as pd
import csv

# %%
df = pd.read_csv('../datasets/creditcard-training set v2.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227844 entries, 0 to 227843
# Data columns (total 32 columns):
# Seconds since reference time       227844 non-null int64
# Amount                             227844 non-null float64
# Fraud? (1: Fraud, 0:  No Fraud)    227844 non-null int64
# Feature 1                          227844 non-null float64
# Feature 2                          227844 non-null float64
# Feature 3                          227844 non-null float64
# Feature 4                          227844 non-null float64
# Feature 5                          227817 non-null float64
# Feature 6                          227785 non-null float64
# Feature 7                          227844 non-null float64
# Feature 8                          227844 non-null float64
# Feature 9                          227844 non-null float64
# Feature 10                         227844 non-null float64
# Feature 11                         227844 non-null float64
# ...

# %%
df.describe()
# Out:
#        Seconds since reference time         Amount  \
# count                 227844.000000  227844.000000
# mean                   79042.504749      90.825317
# std                    39505.785991     250.504249
# min                        0.000000       0.000000
# 25%                    47694.000000       6.000000
# 50%                    73261.000000      23.400000
# 75%                   120396.000000      79.990000
# max                   145245.000000   19656.530000
#
#        Fraud? (1: Fraud, 0:  No Fraud)      Feature 1      Feature 2  \
# count                    227844.000000  227844.000000  227844.000000
# mean                          0.001830       0.049116      -0.005509
# std                           0.042742       0.933915       0.885633
# min                           0.000000      -4.498945     -14.129855
# 25%                           0.000000      -0.543185      -0.478638
# 50%                           0.000000       0.120841       0.059919
# ...

# %%
df.rename(columns={"Seconds since reference time": "Seconds Elapsed"}, inplace=True)
df.rename(columns={"Fraud? (1: Fraud, 0:  No Fraud)": "Fraud"}, inplace=True)
df.head()
# Out:
#    Seconds Elapsed  Amount  Fraud  Feature 1  Feature 2  Feature 3  Feature 4  \
# 0                0  149.62      0   1.468177  -0.470401   0.207971   0.025791
# 1                0    2.69      0   0.635558   0.463917  -0.114805  -0.183361
# 2                1  378.66      0   2.345865  -2.890083   1.109969  -0.121359
# 3                1  123.50      0  -0.631418  -1.059647  -0.684093   1.965775
# 4                2   69.99      0   0.175121  -0.451449  -0.237033  -0.038195
#
#    Feature 5  Feature 6  Feature 7     ...      Feature 20  Feature 21  \
# 0   0.403993   0.251412  -0.018307     ...        0.462388    0.239599
# 1  -0.145783  -0.069083  -0.225775     ...       -0.082361   -0.078803
# 2  -2.261857   0.524980   0.247998     ...        1.800499    0.791461
# 3  -1.232622  -0.208038  -0.108300     ...        1.247203    0.237609
# 4   0.803487   0.408542  -0.009431     ...        0.095921    0.592941
#
# ...

# %%
from keras.models import Sequential, Model, Input 
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import SimpleRNN, GRU, LSTM
from keras.layers.core import Dense, Dropout
from keras.layers.wrappers import TimeDistributed
from keras.layers import Conv1D, MaxPooling1D, Bidirectional, CuDNNGRU, Lambda, concatenate, SpatialDropout1D
import matplotlib.pyplot as plt
import seaborn
# Out:
# Using TensorFlow backend.
